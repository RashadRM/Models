# %%
import pandas as pd  # Import pandas for data manipulation and analysis
import numpy as np  # Import numpy for numerical operations
from sklearn.model_selection import train_test_split  # Import train_test_split for splitting data into training and testing sets
from sklearn.preprocessing import StandardScaler, LabelEncoder  # Import StandardScaler for feature scaling and LabelEncoder for encoding target labels
from xgboost import XGBClassifier  # Import XGBClassifier for XGBoost model
from lightgbm import LGBMClassifier  # Import LGBMClassifier for LightGBM model
from catboost import CatBoostClassifier  # Import CatBoostClassifier for CatBoost model
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, roc_auc_score  # Import specific metrics for model evaluation
import warnings  # Import warnings to manage warnings
import category_encoders as ce  # Import category_encoders for encoding categorical features
import optuna
# Ignore warnings
warnings.filterwarnings('ignore')  # Suppress warnings for cleaner output

# %%
path = r'C:\Users\User\Desktop\Rashad\DATA\Thyroid_Diff.csv'

# Load dataset from Excel file
df = pd.read_csv(path)

# Set option to display all columns
pd.set_option('display.max_columns', None)

#Display the loaded dataset
df
# Out:
#      Age Gender Smoking Hx Smoking Hx Radiothreapy          Thyroid Function  \
# 0     27      F      No         No              No                 Euthyroid
# 1     34      F      No        Yes              No                 Euthyroid
# 2     30      F      No         No              No                 Euthyroid
# 3     62      F      No         No              No                 Euthyroid
# 4     62      F      No         No              No                 Euthyroid
# ..   ...    ...     ...        ...             ...                       ...
# 378   72      M     Yes        Yes             Yes                 Euthyroid
# 379   81      M     Yes         No             Yes                 Euthyroid
# 380   72      M     Yes        Yes              No                 Euthyroid
# 381   61      M     Yes        Yes             Yes  Clinical Hyperthyroidism
# 382   67      M     Yes         No              No                 Euthyroid
#
#             Physical Examination Adenopathy       Pathology     Focality  \
# 0     Single nodular goiter-left         No  Micropapillary    Uni-Focal
# 1            Multinodular goiter         No  Micropapillary    Uni-Focal
# 2    Single nodular goiter-right         No  Micropapillary    Uni-Focal
# 3    Single nodular goiter-right         No  Micropapillary    Uni-Focal
# 4            Multinodular goiter         No  Micropapillary  Multi-Focal
# ..                           ...        ...             ...          ...
# 378  Single nodular goiter-right      Right       Papillary    Uni-Focal
# 379          Multinodular goiter  Extensive       Papillary  Multi-Focal
# 380          Multinodular goiter  Bilateral       Papillary  Multi-Focal
# 381          Multinodular goiter  Extensive    Hurthel cell  Multi-Focal
# 382          Multinodular goiter  Bilateral       Papillary  Multi-Focal
#
#      Risk    T    N   M Stage                Response Recurred
# 0     Low  T1a   N0  M0     I           Indeterminate       No
# 1     Low  T1a   N0  M0     I               Excellent       No
# 2     Low  T1a   N0  M0     I               Excellent       No
# 3     Low  T1a   N0  M0     I               Excellent       No
# 4     Low  T1a   N0  M0     I               Excellent       No
# ..    ...  ...  ...  ..   ...                     ...      ...
# 378  High  T4b  N1b  M1   IVB  Biochemical Incomplete      Yes
# 379  High  T4b  N1b  M1   IVB   Structural Incomplete      Yes
# 380  High  T4b  N1b  M1   IVB   Structural Incomplete      Yes
# 381  High  T4b  N1b  M0   IVA   Structural Incomplete      Yes
# 382  High  T4b  N1b  M0   IVA   Structural Incomplete      Yes
#
# [383 rows x 17 columns]

# %%
df['Recurred'] = df['Recurred'].map({'No': 0, 'Yes': 1})

# %%
models = ["xgboost", "lightgbm", "catboost", "catboost_custom"]

# Create copies of the DataFrame for different preprocessing approaches
df_boost = df.copy()
df_cat = df.copy()

# Iterate through each model in the list
for model in models:            
    if model in ["xgboost", "lightgbm", "catboost"]:
        # Preprocessing for tree-based models
        
        # Perform Weight of Evidence Encoding on all columns except the target column 'default'
        all_columns = df_boost.columns.tolist()
        all_columns.remove('Recurred')
        encoder = ce.WOEEncoder(cols=all_columns)
        df_boost[all_columns] = encoder.fit_transform(df_boost[all_columns], df_boost['Recurred'])
             
    elif model ==  "catboost_custom":
        # Preprocessing for CatBoost with custom handling of missing values
        
        # Fill missing values in specified categorical columns with 'Missing Value'
        numerical_cols = df_cat.select_dtypes(include=['int64', 'float64']).columns.tolist()
        numerical_cols.remove('Recurred')
        columns_to_fill = cat_features=['Gender', 'Smoking', 'Hx Smoking', 'Hx Radiothreapy',
       'Thyroid Function', 'Physical Examination', 'Adenopathy', 'Pathology',
       'Focality', 'Risk', 'T', 'N', 'M', 'Stage', 'Response']
        df_cat[columns_to_fill] = df_cat[columns_to_fill].fillna('Missing Value')
        
        # Perform Weight of Evidence Encoding on numerical columns
        cat_encoder = ce.WOEEncoder(cols=numerical_cols)
        df_cat[numerical_cols] = cat_encoder.fit_transform(df_cat[numerical_cols], df_cat['Recurred'])

# Split data into features (X) and target (y) for each preprocessing approach
x_boost = df_boost.drop(columns=['Recurred'])
y_boost = df_boost['Recurred']
X_train_boost, X_test_boost, y_train_boost, y_test_boost = train_test_split(x_boost, y_boost, test_size=0.3, random_state=42)

x_cat = df_cat.drop(columns=['Recurred'])
y_cat = df_cat['Recurred']
X_train_cat, X_test_cat, y_train_cat, y_test_cat = train_test_split(x_cat, y_cat, test_size=0.3, random_state=42)

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['Gender', 'Smoking', 'Hx Smoking', 'Hx Radiothreapy',
#        'Thyroid Function', 'Physical Examination', 'Adenopathy', 'Pathology',
#        'Focality', 'Risk', 'T', 'N', 'M', 'Stage', 'Response'],
#       dtype='object')

# %%
models = []

xgb_model_def = XGBClassifier()
lgb_model_def = LGBMClassifier()
catboost_model_def = CatBoostClassifier()
catboost_model_custom = CatBoostClassifier(cat_features=['Gender', 'Smoking', 'Hx Smoking', 'Hx Radiothreapy',
                   'Thyroid Function', 'Physical Examination', 'Adenopathy', 'Pathology',
                   'Focality', 'Risk', 'T', 'N', 'M', 'Stage', 'Response'])

models.extend([
    ('XGBoost', xgb_model_def),
    ('LightGBM', lgb_model_def),
    ('CatBoost', catboost_model_def),
    ('CatBoost_Custom', catboost_model_custom),
])

# %%
def train_and_evaluate_model(model_name, model, X_train, y_train, X_test, y_test):
    """
    Train and evaluate the given model on the training and testing data.

    Parameters:
    model_name (str): Name of the model for display purposes.
    model : Machine learning model object.
    X_train : Features of the training data.
    y_train : Target labels of the training data.
    X_test : Features of the testing data.
    y_test : Target labels of the testing data.

    Returns:
    float: Gini coefficient calculated from the model's predictions.
    """

    # Fit the model on the training data
    model.fit(X_train, y_train)

    # Predict labels and probabilities on the testing data
    y_pred = model.predict(X_test)
    y_prob = model.predict_proba(X_test)[:, 1]

    # Calculate ROC AUC and Gini coefficient
    roc_prob = roc_auc_score(y_test, y_prob)
    gini_prob = roc_prob * 2 - 1

    # Calculate confusion matrix and classification report
    confusion_matrix_result = confusion_matrix(y_test, y_pred)
    classification_report_result = classification_report(y_test, y_pred)

    # Print model performance metrics
    print(f'Model Performance for {model_name}')
    print('Gini prob is', gini_prob * 100)
    print(classification_report_result)
    print(confusion_matrix_result)

    return gini_prob

# %%
gini_df = pd.DataFrame(columns=['Model', 'Gini_prob'])

# Iterate through each model in the list of models
for model_name, model in models:
    # Train and evaluate the model, and calculate the Gini coefficient
    if model_name == 'CatBoost_Custom':
        gini_prob = train_and_evaluate_model(model_name, model, X_train_cat, y_train_cat, X_test_cat, y_test_cat)
    else:
        gini_prob = train_and_evaluate_model(model_name, model, X_train_boost, y_train_boost, X_test_boost, y_test_boost)
        
    # Add model name and Gini coefficient to the DataFrame
    if gini_prob is not None:
        gini_df = pd.concat([gini_df, pd.DataFrame({'Model': [model_name], 'Gini_prob': [gini_prob]})], ignore_index=True)

# Sort the DataFrame by Gini coefficient in descending order
gini_df_sorted = gini_df.sort_values(by='Gini_prob', ascending=False)
# Out:
# Model Performance for XGBoost
# Gini prob is 97.81626506024097
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97        83
#            1       0.91      0.94      0.92        32
#
#     accuracy                           0.96       115
#    macro avg       0.94      0.95      0.95       115
# weighted avg       0.96      0.96      0.96       115
#
# [[80  3]
#  [ 2 30]]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 76, number of negative: 192
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001152 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 85
# [LightGBM] [Info] Number of data points in the train set: 268, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.283582 -> initscore=-0.926762
# [LightGBM] [Info] Start training from score -0.926762
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Model Performance for LightGBM
# Gini prob is 97.66566265060239
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.96        83
#            1       0.88      0.94      0.91        32
#
#     accuracy                           0.95       115
#    macro avg       0.93      0.94      0.94       115
# weighted avg       0.95      0.95      0.95       115
#
# [[79  4]
#  [ 2 30]]
# Learning rate set to 0.005871
# 0:	learn: 0.6823783	total: 202ms	remaining: 3m 21s
# 1:	learn: 0.6737527	total: 207ms	remaining: 1m 43s
# 2:	learn: 0.6637002	total: 212ms	remaining: 1m 10s
# 3:	learn: 0.6550064	total: 217ms	remaining: 54s
# 4:	learn: 0.6464094	total: 221ms	remaining: 44.1s
# 5:	learn: 0.6361207	total: 226ms	remaining: 37.5s
# 6:	learn: 0.6281269	total: 230ms	remaining: 32.7s
# 7:	learn: 0.6198625	total: 235ms	remaining: 29.1s
# 8:	learn: 0.6104445	total: 240ms	remaining: 26.4s
# 9:	learn: 0.6031434	total: 244ms	remaining: 24.2s
# 10:	learn: 0.5960985	total: 249ms	remaining: 22.4s
# 11:	learn: 0.5876681	total: 254ms	remaining: 20.9s
# 12:	learn: 0.5789277	total: 258ms	remaining: 19.6s
# 13:	learn: 0.5703934	total: 263ms	remaining: 18.5s
# 14:	learn: 0.5625039	total: 267ms	remaining: 17.5s
# 15:	learn: 0.5542538	total: 272ms	remaining: 16.7s
# 16:	learn: 0.5459863	total: 276ms	remaining: 16s
# 17:	learn: 0.5386835	total: 281ms	remaining: 15.3s
# 18:	learn: 0.5329855	total: 285ms	remaining: 14.7s
# 19:	learn: 0.5266106	total: 288ms	remaining: 14.1s
# 20:	learn: 0.5188870	total: 291ms	remaining: 13.6s
# 21:	learn: 0.5132701	total: 293ms	remaining: 13s
# 22:	learn: 0.5077692	total: 296ms	remaining: 12.6s
# 23:	learn: 0.4997489	total: 299ms	remaining: 12.1s
# 24:	learn: 0.4925016	total: 301ms	remaining: 11.8s
# 25:	learn: 0.4855541	total: 304ms	remaining: 11.4s
# 266:	learn: 0.0953857	total: 948ms	remaining: 2.6s
# 267:	learn: 0.0950452	total: 950ms	remaining: 2.6s
# 268:	learn: 0.0946778	total: 953ms	remaining: 2.59s
# 269:	learn: 0.0943281	total: 956ms	remaining: 2.58s
# 270:	learn: 0.0940831	total: 959ms	remaining: 2.58s
# 271:	learn: 0.0938137	total: 962ms	remaining: 2.57s
# 272:	learn: 0.0935036	total: 964ms	remaining: 2.57s
# 273:	learn: 0.0931549	total: 967ms	remaining: 2.56s
# 274:	learn: 0.0928792	total: 969ms	remaining: 2.56s
# 275:	learn: 0.0925500	total: 973ms	remaining: 2.55s
# 276:	learn: 0.0922677	total: 976ms	remaining: 2.55s
# 277:	learn: 0.0919228	total: 981ms	remaining: 2.55s
# 278:	learn: 0.0915728	total: 983ms	remaining: 2.54s
# 279:	learn: 0.0912619	total: 986ms	remaining: 2.54s
# 280:	learn: 0.0908912	total: 989ms	remaining: 2.53s
# 281:	learn: 0.0904957	total: 992ms	remaining: 2.52s
# 282:	learn: 0.0903291	total: 994ms	remaining: 2.52s
# 283:	learn: 0.0899818	total: 996ms	remaining: 2.51s
# 284:	learn: 0.0897171	total: 998ms	remaining: 2.5s
# 285:	learn: 0.0894233	total: 1s	remaining: 2.5s
# 286:	learn: 0.0891852	total: 1s	remaining: 2.49s
# 287:	learn: 0.0890885	total: 1s	remaining: 2.48s
# 288:	learn: 0.0887380	total: 1.01s	remaining: 2.48s
# 289:	learn: 0.0884419	total: 1.01s	remaining: 2.48s
# 290:	learn: 0.0883487	total: 1.01s	remaining: 2.47s
# 291:	learn: 0.0882447	total: 1.01s	remaining: 2.46s
# 292:	learn: 0.0879390	total: 1.02s	remaining: 2.46s
# 293:	learn: 0.0877065	total: 1.02s	remaining: 2.45s
# 294:	learn: 0.0875482	total: 1.02s	remaining: 2.44s
# 295:	learn: 0.0872092	total: 1.02s	remaining: 2.44s
# 296:	learn: 0.0868558	total: 1.03s	remaining: 2.43s
# 297:	learn: 0.0865138	total: 1.03s	remaining: 2.43s
# 298:	learn: 0.0863148	total: 1.03s	remaining: 2.42s
# 299:	learn: 0.0860213	total: 1.04s	remaining: 2.42s
# 300:	learn: 0.0857532	total: 1.04s	remaining: 2.41s
# 301:	learn: 0.0855697	total: 1.04s	remaining: 2.41s
# 302:	learn: 0.0853893	total: 1.04s	remaining: 2.4s
# 303:	learn: 0.0850957	total: 1.05s	remaining: 2.4s
# 304:	learn: 0.0848141	total: 1.05s	remaining: 2.39s
# 305:	learn: 0.0844932	total: 1.05s	remaining: 2.39s
# 306:	learn: 0.0841747	total: 1.05s	remaining: 2.38s
# 307:	learn: 0.0838902	total: 1.06s	remaining: 2.38s
# 308:	learn: 0.0835567	total: 1.06s	remaining: 2.37s
# 309:	learn: 0.0834974	total: 1.06s	remaining: 2.37s
# 310:	learn: 0.0832638	total: 1.07s	remaining: 2.36s
# 311:	learn: 0.0829056	total: 1.07s	remaining: 2.36s
# 312:	learn: 0.0826143	total: 1.07s	remaining: 2.35s
# 313:	learn: 0.0824608	total: 1.07s	remaining: 2.35s
# 314:	learn: 0.0821311	total: 1.08s	remaining: 2.34s
# 315:	learn: 0.0818652	total: 1.08s	remaining: 2.34s
# 316:	learn: 0.0817514	total: 1.08s	remaining: 2.33s
# 317:	learn: 0.0815050	total: 1.08s	remaining: 2.33s
# 318:	learn: 0.0812192	total: 1.09s	remaining: 2.32s
# 319:	learn: 0.0809826	total: 1.09s	remaining: 2.32s
# 320:	learn: 0.0807242	total: 1.09s	remaining: 2.31s
# 321:	learn: 0.0805584	total: 1.1s	remaining: 2.31s
# 322:	learn: 0.0803649	total: 1.1s	remaining: 2.3s
# 323:	learn: 0.0801169	total: 1.1s	remaining: 2.3s
# 324:	learn: 0.0798957	total: 1.1s	remaining: 2.29s
# 325:	learn: 0.0796451	total: 1.11s	remaining: 2.29s
# 326:	learn: 0.0794667	total: 1.11s	remaining: 2.29s
# 327:	learn: 0.0792298	total: 1.11s	remaining: 2.28s
# 328:	learn: 0.0789496	total: 1.11s	remaining: 2.28s
# 329:	learn: 0.0786930	total: 1.12s	remaining: 2.27s
# 330:	learn: 0.0785561	total: 1.12s	remaining: 2.27s
# 331:	learn: 0.0782793	total: 1.12s	remaining: 2.26s
# 332:	learn: 0.0780134	total: 1.13s	remaining: 2.26s
# 333:	learn: 0.0779584	total: 1.13s	remaining: 2.25s
# 334:	learn: 0.0778053	total: 1.13s	remaining: 2.25s
# 335:	learn: 0.0776080	total: 1.13s	remaining: 2.24s
# 336:	learn: 0.0773703	total: 1.14s	remaining: 2.24s
# 337:	learn: 0.0772196	total: 1.14s	remaining: 2.23s
# 338:	learn: 0.0770441	total: 1.14s	remaining: 2.23s
# 339:	learn: 0.0768489	total: 1.15s	remaining: 2.22s
# 340:	learn: 0.0766594	total: 1.15s	remaining: 2.22s
# 341:	learn: 0.0764277	total: 1.15s	remaining: 2.21s
# 342:	learn: 0.0761958	total: 1.15s	remaining: 2.21s
# 343:	learn: 0.0760507	total: 1.16s	remaining: 2.21s
# 344:	learn: 0.0758322	total: 1.16s	remaining: 2.2s
# 345:	learn: 0.0756942	total: 1.16s	remaining: 2.2s
# 346:	learn: 0.0753375	total: 1.16s	remaining: 2.19s
# 347:	learn: 0.0750818	total: 1.17s	remaining: 2.19s
# 348:	learn: 0.0749124	total: 1.17s	remaining: 2.18s
# 349:	learn: 0.0746588	total: 1.17s	remaining: 2.18s
# 350:	learn: 0.0744290	total: 1.18s	remaining: 2.18s
# 351:	learn: 0.0742674	total: 1.18s	remaining: 2.17s
# 352:	learn: 0.0740569	total: 1.18s	remaining: 2.17s
# 353:	learn: 0.0738723	total: 1.18s	remaining: 2.16s
# 354:	learn: 0.0736740	total: 1.19s	remaining: 2.15s
# 355:	learn: 0.0734811	total: 1.19s	remaining: 2.15s
# 356:	learn: 0.0732650	total: 1.19s	remaining: 2.14s
# 357:	learn: 0.0730052	total: 1.19s	remaining: 2.14s
# 358:	learn: 0.0728709	total: 1.2s	remaining: 2.13s
# 359:	learn: 0.0725866	total: 1.2s	remaining: 2.13s
# 360:	learn: 0.0723372	total: 1.2s	remaining: 2.13s
# 361:	learn: 0.0721853	total: 1.2s	remaining: 2.12s
# 362:	learn: 0.0719677	total: 1.21s	remaining: 2.12s
# 363:	learn: 0.0717978	total: 1.21s	remaining: 2.11s
# 364:	learn: 0.0716266	total: 1.21s	remaining: 2.11s
# 365:	learn: 0.0714816	total: 1.21s	remaining: 2.1s
# 366:	learn: 0.0713493	total: 1.22s	remaining: 2.1s
# 367:	learn: 0.0711832	total: 1.22s	remaining: 2.1s
# 368:	learn: 0.0710043	total: 1.22s	remaining: 2.09s
# 369:	learn: 0.0708108	total: 1.23s	remaining: 2.09s
# 370:	learn: 0.0706047	total: 1.23s	remaining: 2.08s
# 371:	learn: 0.0704088	total: 1.23s	remaining: 2.08s
# 372:	learn: 0.0702098	total: 1.23s	remaining: 2.07s
# 373:	learn: 0.0700376	total: 1.24s	remaining: 2.07s
# 374:	learn: 0.0698708	total: 1.24s	remaining: 2.06s
# 375:	learn: 0.0698436	total: 1.24s	remaining: 2.06s
# 376:	learn: 0.0696420	total: 1.24s	remaining: 2.06s
# 377:	learn: 0.0696131	total: 1.25s	remaining: 2.05s
# 378:	learn: 0.0693957	total: 1.25s	remaining: 2.05s
# 379:	learn: 0.0691565	total: 1.25s	remaining: 2.04s
# 380:	learn: 0.0689295	total: 1.25s	remaining: 2.04s
# 381:	learn: 0.0686645	total: 1.26s	remaining: 2.03s
# 382:	learn: 0.0685434	total: 1.26s	remaining: 2.03s
# 383:	learn: 0.0683882	total: 1.26s	remaining: 2.02s
# 384:	learn: 0.0681702	total: 1.26s	remaining: 2.02s
# 385:	learn: 0.0679824	total: 1.27s	remaining: 2.02s
# 386:	learn: 0.0677931	total: 1.27s	remaining: 2.01s
# 387:	learn: 0.0675446	total: 1.27s	remaining: 2.01s
# 388:	learn: 0.0674042	total: 1.27s	remaining: 2s
# 389:	learn: 0.0672129	total: 1.28s	remaining: 2s
# 390:	learn: 0.0669679	total: 1.28s	remaining: 2s
# 391:	learn: 0.0667944	total: 1.28s	remaining: 1.99s
# 392:	learn: 0.0666467	total: 1.29s	remaining: 1.99s
# 393:	learn: 0.0664826	total: 1.29s	remaining: 1.98s
# 394:	learn: 0.0663391	total: 1.29s	remaining: 1.98s
# 395:	learn: 0.0661578	total: 1.29s	remaining: 1.97s
# 396:	learn: 0.0659372	total: 1.3s	remaining: 1.97s
# 397:	learn: 0.0657602	total: 1.3s	remaining: 1.97s
# 398:	learn: 0.0655870	total: 1.3s	remaining: 1.96s
# 399:	learn: 0.0653707	total: 1.3s	remaining: 1.96s
# 400:	learn: 0.0651462	total: 1.31s	remaining: 1.95s
# 401:	learn: 0.0649699	total: 1.31s	remaining: 1.95s
# 402:	learn: 0.0647973	total: 1.31s	remaining: 1.94s
# 403:	learn: 0.0646570	total: 1.31s	remaining: 1.94s
# 404:	learn: 0.0645352	total: 1.32s	remaining: 1.94s
# 405:	learn: 0.0643280	total: 1.32s	remaining: 1.93s
# 406:	learn: 0.0641861	total: 1.32s	remaining: 1.93s
# 407:	learn: 0.0640725	total: 1.33s	remaining: 1.92s
# 408:	learn: 0.0638583	total: 1.33s	remaining: 1.92s
# 409:	learn: 0.0636805	total: 1.33s	remaining: 1.92s
# 410:	learn: 0.0634654	total: 1.33s	remaining: 1.91s
# 411:	learn: 0.0633450	total: 1.34s	remaining: 1.91s
# 412:	learn: 0.0631781	total: 1.34s	remaining: 1.9s
# 413:	learn: 0.0629895	total: 1.34s	remaining: 1.9s
# 414:	learn: 0.0628191	total: 1.34s	remaining: 1.9s
# 415:	learn: 0.0626752	total: 1.35s	remaining: 1.89s
# 416:	learn: 0.0626518	total: 1.35s	remaining: 1.89s
# 417:	learn: 0.0625005	total: 1.35s	remaining: 1.88s
# 418:	learn: 0.0622642	total: 1.35s	remaining: 1.88s
# 419:	learn: 0.0620815	total: 1.36s	remaining: 1.87s
# 420:	learn: 0.0618307	total: 1.36s	remaining: 1.87s
# 421:	learn: 0.0617119	total: 1.36s	remaining: 1.87s
# 422:	learn: 0.0615284	total: 1.36s	remaining: 1.86s
# 423:	learn: 0.0613735	total: 1.37s	remaining: 1.86s
# 424:	learn: 0.0611886	total: 1.37s	remaining: 1.85s
# 425:	learn: 0.0609953	total: 1.37s	remaining: 1.85s
# 426:	learn: 0.0607508	total: 1.38s	remaining: 1.84s
# 427:	learn: 0.0606035	total: 1.38s	remaining: 1.84s
# 428:	learn: 0.0604426	total: 1.38s	remaining: 1.84s
# 429:	learn: 0.0603377	total: 1.38s	remaining: 1.83s
# 430:	learn: 0.0601485	total: 1.38s	remaining: 1.83s
# 431:	learn: 0.0600373	total: 1.39s	remaining: 1.82s
# 432:	learn: 0.0598721	total: 1.39s	remaining: 1.82s
# 433:	learn: 0.0597227	total: 1.39s	remaining: 1.81s
# 434:	learn: 0.0596142	total: 1.39s	remaining: 1.81s
# 435:	learn: 0.0594659	total: 1.4s	remaining: 1.81s
# 436:	learn: 0.0593361	total: 1.4s	remaining: 1.8s
# 437:	learn: 0.0591701	total: 1.4s	remaining: 1.8s
# 438:	learn: 0.0589864	total: 1.41s	remaining: 1.79s
# 439:	learn: 0.0588480	total: 1.41s	remaining: 1.79s
# 440:	learn: 0.0587355	total: 1.41s	remaining: 1.79s
# 441:	learn: 0.0586192	total: 1.41s	remaining: 1.78s
# 442:	learn: 0.0584832	total: 1.42s	remaining: 1.78s
# 443:	learn: 0.0583402	total: 1.42s	remaining: 1.78s
# 444:	learn: 0.0582224	total: 1.42s	remaining: 1.77s
# 445:	learn: 0.0580116	total: 1.42s	remaining: 1.77s
# 446:	learn: 0.0578370	total: 1.43s	remaining: 1.76s
# 447:	learn: 0.0576979	total: 1.43s	remaining: 1.76s
# 448:	learn: 0.0575736	total: 1.43s	remaining: 1.76s
# 449:	learn: 0.0574331	total: 1.44s	remaining: 1.75s
# 450:	learn: 0.0573023	total: 1.44s	remaining: 1.75s
# 451:	learn: 0.0572018	total: 1.44s	remaining: 1.75s
# 452:	learn: 0.0570384	total: 1.44s	remaining: 1.74s
# 453:	learn: 0.0569294	total: 1.45s	remaining: 1.74s
# 454:	learn: 0.0567645	total: 1.45s	remaining: 1.73s
# 455:	learn: 0.0566777	total: 1.45s	remaining: 1.73s
# 456:	learn: 0.0565331	total: 1.45s	remaining: 1.73s
# 457:	learn: 0.0563564	total: 1.46s	remaining: 1.72s
# 458:	learn: 0.0562031	total: 1.46s	remaining: 1.72s
# 459:	learn: 0.0560543	total: 1.46s	remaining: 1.72s
# 460:	learn: 0.0559127	total: 1.46s	remaining: 1.71s
# 461:	learn: 0.0557697	total: 1.47s	remaining: 1.71s
# 462:	learn: 0.0556174	total: 1.47s	remaining: 1.7s
# 463:	learn: 0.0554943	total: 1.47s	remaining: 1.7s
# 464:	learn: 0.0553981	total: 1.47s	remaining: 1.7s
# 465:	learn: 0.0553636	total: 1.48s	remaining: 1.69s
# 466:	learn: 0.0552075	total: 1.48s	remaining: 1.69s
# 467:	learn: 0.0551024	total: 1.48s	remaining: 1.68s
# 468:	learn: 0.0549698	total: 1.48s	remaining: 1.68s
# 469:	learn: 0.0548505	total: 1.49s	remaining: 1.68s
# 470:	learn: 0.0546871	total: 1.49s	remaining: 1.67s
# 471:	learn: 0.0545876	total: 1.49s	remaining: 1.67s
# 472:	learn: 0.0544755	total: 1.5s	remaining: 1.67s
# 473:	learn: 0.0543045	total: 1.5s	remaining: 1.66s
# 474:	learn: 0.0541762	total: 1.5s	remaining: 1.66s
# 475:	learn: 0.0540916	total: 1.5s	remaining: 1.65s
# 476:	learn: 0.0538828	total: 1.5s	remaining: 1.65s
# 477:	learn: 0.0537685	total: 1.51s	remaining: 1.65s
# 478:	learn: 0.0536563	total: 1.51s	remaining: 1.64s
# 479:	learn: 0.0535775	total: 1.51s	remaining: 1.64s
# 480:	learn: 0.0534858	total: 1.51s	remaining: 1.63s
# 481:	learn: 0.0533436	total: 1.52s	remaining: 1.63s
# 482:	learn: 0.0532790	total: 1.52s	remaining: 1.63s
# 483:	learn: 0.0531322	total: 1.52s	remaining: 1.62s
# 484:	learn: 0.0529805	total: 1.52s	remaining: 1.62s
# 485:	learn: 0.0528322	total: 1.53s	remaining: 1.62s
# 486:	learn: 0.0527097	total: 1.53s	remaining: 1.61s
# 487:	learn: 0.0526091	total: 1.53s	remaining: 1.61s
# 488:	learn: 0.0524674	total: 1.54s	remaining: 1.61s
# 489:	learn: 0.0523610	total: 1.54s	remaining: 1.6s
# 490:	learn: 0.0522372	total: 1.54s	remaining: 1.6s
# 491:	learn: 0.0521256	total: 1.55s	remaining: 1.6s
# 492:	learn: 0.0519315	total: 1.55s	remaining: 1.59s
# 493:	learn: 0.0518485	total: 1.55s	remaining: 1.59s
# 494:	learn: 0.0517109	total: 1.56s	remaining: 1.59s
# 495:	learn: 0.0515764	total: 1.56s	remaining: 1.58s
# 496:	learn: 0.0514372	total: 1.56s	remaining: 1.58s
# 497:	learn: 0.0513073	total: 1.56s	remaining: 1.58s
# 498:	learn: 0.0512189	total: 1.57s	remaining: 1.57s
# 499:	learn: 0.0510872	total: 1.57s	remaining: 1.57s
# 500:	learn: 0.0509874	total: 1.57s	remaining: 1.57s
# 501:	learn: 0.0508731	total: 1.58s	remaining: 1.56s
# 502:	learn: 0.0507516	total: 1.58s	remaining: 1.56s
# 503:	learn: 0.0506239	total: 1.58s	remaining: 1.56s
# 504:	learn: 0.0504697	total: 1.58s	remaining: 1.55s
# 505:	learn: 0.0503182	total: 1.59s	remaining: 1.55s
# 506:	learn: 0.0501956	total: 1.59s	remaining: 1.55s
# 507:	learn: 0.0500891	total: 1.59s	remaining: 1.54s
# 508:	learn: 0.0499742	total: 1.6s	remaining: 1.54s
# 509:	learn: 0.0498692	total: 1.6s	remaining: 1.54s
# 510:	learn: 0.0497353	total: 1.6s	remaining: 1.53s
# 511:	learn: 0.0496092	total: 1.6s	remaining: 1.53s
# 512:	learn: 0.0494619	total: 1.61s	remaining: 1.53s
# 513:	learn: 0.0493699	total: 1.61s	remaining: 1.52s
# 514:	learn: 0.0492692	total: 1.61s	remaining: 1.52s
# 515:	learn: 0.0491730	total: 1.61s	remaining: 1.51s
# 516:	learn: 0.0490552	total: 1.62s	remaining: 1.51s
# 517:	learn: 0.0489687	total: 1.62s	remaining: 1.51s
# 518:	learn: 0.0488315	total: 1.62s	remaining: 1.5s
# 519:	learn: 0.0487607	total: 1.63s	remaining: 1.5s
# 520:	learn: 0.0486567	total: 1.63s	remaining: 1.5s
# 521:	learn: 0.0485137	total: 1.63s	remaining: 1.49s
# 522:	learn: 0.0483897	total: 1.63s	remaining: 1.49s
# 523:	learn: 0.0483018	total: 1.64s	remaining: 1.49s
# 524:	learn: 0.0481834	total: 1.64s	remaining: 1.48s
# 525:	learn: 0.0480918	total: 1.64s	remaining: 1.48s
# 526:	learn: 0.0479886	total: 1.64s	remaining: 1.47s
# 527:	learn: 0.0478893	total: 1.64s	remaining: 1.47s
# 528:	learn: 0.0478028	total: 1.65s	remaining: 1.47s
# 529:	learn: 0.0476710	total: 1.65s	remaining: 1.46s
# 530:	learn: 0.0475375	total: 1.65s	remaining: 1.46s
# 531:	learn: 0.0475173	total: 1.65s	remaining: 1.45s
# 532:	learn: 0.0474318	total: 1.66s	remaining: 1.45s
# 533:	learn: 0.0473416	total: 1.66s	remaining: 1.45s
# 534:	learn: 0.0472242	total: 1.66s	remaining: 1.44s
# 535:	learn: 0.0471671	total: 1.66s	remaining: 1.44s
# 536:	learn: 0.0470543	total: 1.67s	remaining: 1.44s
# 537:	learn: 0.0469513	total: 1.67s	remaining: 1.43s
# 538:	learn: 0.0468417	total: 1.67s	remaining: 1.43s
# 539:	learn: 0.0467477	total: 1.67s	remaining: 1.43s
# 540:	learn: 0.0466142	total: 1.68s	remaining: 1.42s
# 541:	learn: 0.0465130	total: 1.68s	remaining: 1.42s
# 542:	learn: 0.0464378	total: 1.68s	remaining: 1.42s
# 543:	learn: 0.0463074	total: 1.69s	remaining: 1.41s
# 544:	learn: 0.0462160	total: 1.69s	remaining: 1.41s
# 545:	learn: 0.0461120	total: 1.69s	remaining: 1.41s
# 546:	learn: 0.0460489	total: 1.69s	remaining: 1.4s
# 547:	learn: 0.0459636	total: 1.7s	remaining: 1.4s
# 548:	learn: 0.0459126	total: 1.7s	remaining: 1.39s
# 549:	learn: 0.0457759	total: 1.7s	remaining: 1.39s
# 550:	learn: 0.0456967	total: 1.7s	remaining: 1.39s
# 551:	learn: 0.0455935	total: 1.7s	remaining: 1.38s
# 552:	learn: 0.0454822	total: 1.71s	remaining: 1.38s
# 553:	learn: 0.0453558	total: 1.71s	remaining: 1.38s
# 554:	learn: 0.0452970	total: 1.71s	remaining: 1.37s
# 555:	learn: 0.0451919	total: 1.71s	remaining: 1.37s
# 556:	learn: 0.0451049	total: 1.72s	remaining: 1.36s
# 557:	learn: 0.0450062	total: 1.72s	remaining: 1.36s
# 558:	learn: 0.0449564	total: 1.72s	remaining: 1.36s
# 559:	learn: 0.0448442	total: 1.72s	remaining: 1.35s
# 560:	learn: 0.0447689	total: 1.73s	remaining: 1.35s
# 561:	learn: 0.0446991	total: 1.73s	remaining: 1.35s
# 562:	learn: 0.0446220	total: 1.73s	remaining: 1.34s
# 563:	learn: 0.0445365	total: 1.73s	remaining: 1.34s
# 564:	learn: 0.0444264	total: 1.74s	remaining: 1.34s
# 565:	learn: 0.0443850	total: 1.74s	remaining: 1.33s
# 566:	learn: 0.0443042	total: 1.74s	remaining: 1.33s
# 567:	learn: 0.0442312	total: 1.74s	remaining: 1.32s
# 568:	learn: 0.0441496	total: 1.75s	remaining: 1.32s
# 569:	learn: 0.0440445	total: 1.75s	remaining: 1.32s
# 570:	learn: 0.0440000	total: 1.75s	remaining: 1.31s
# 571:	learn: 0.0439078	total: 1.75s	remaining: 1.31s
# 572:	learn: 0.0438003	total: 1.76s	remaining: 1.31s
# 573:	learn: 0.0437169	total: 1.76s	remaining: 1.3s
# 574:	learn: 0.0436593	total: 1.76s	remaining: 1.3s
# 575:	learn: 0.0435835	total: 1.76s	remaining: 1.3s
# 576:	learn: 0.0434830	total: 1.77s	remaining: 1.29s
# 577:	learn: 0.0434187	total: 1.77s	remaining: 1.29s
# 578:	learn: 0.0433840	total: 1.77s	remaining: 1.29s
# 579:	learn: 0.0433215	total: 1.77s	remaining: 1.28s
# 580:	learn: 0.0432059	total: 1.77s	remaining: 1.28s
# 581:	learn: 0.0431236	total: 1.78s	remaining: 1.28s
# 582:	learn: 0.0430389	total: 1.78s	remaining: 1.27s
# 583:	learn: 0.0429392	total: 1.78s	remaining: 1.27s
# 584:	learn: 0.0428637	total: 1.78s	remaining: 1.26s
# 585:	learn: 0.0427968	total: 1.79s	remaining: 1.26s
# 586:	learn: 0.0427091	total: 1.79s	remaining: 1.26s
# 587:	learn: 0.0425745	total: 1.79s	remaining: 1.26s
# 588:	learn: 0.0424823	total: 1.8s	remaining: 1.25s
# 589:	learn: 0.0423986	total: 1.8s	remaining: 1.25s
# 590:	learn: 0.0423388	total: 1.8s	remaining: 1.25s
# 591:	learn: 0.0422060	total: 1.8s	remaining: 1.24s
# 592:	learn: 0.0421820	total: 1.81s	remaining: 1.24s
# 593:	learn: 0.0421157	total: 1.81s	remaining: 1.24s
# 594:	learn: 0.0420596	total: 1.81s	remaining: 1.23s
# 595:	learn: 0.0419926	total: 1.81s	remaining: 1.23s
# 596:	learn: 0.0419175	total: 1.82s	remaining: 1.23s
# 597:	learn: 0.0418491	total: 1.82s	remaining: 1.22s
# 598:	learn: 0.0417658	total: 1.82s	remaining: 1.22s
# 599:	learn: 0.0417440	total: 1.83s	remaining: 1.22s
# 600:	learn: 0.0416683	total: 1.83s	remaining: 1.21s
# 601:	learn: 0.0416123	total: 1.83s	remaining: 1.21s
# 602:	learn: 0.0415410	total: 1.83s	remaining: 1.21s
# 603:	learn: 0.0414405	total: 1.84s	remaining: 1.2s
# 604:	learn: 0.0413519	total: 1.84s	remaining: 1.2s
# 605:	learn: 0.0412712	total: 1.84s	remaining: 1.2s
# 606:	learn: 0.0411478	total: 1.85s	remaining: 1.2s
# 607:	learn: 0.0410710	total: 1.85s	remaining: 1.19s
# 608:	learn: 0.0410598	total: 1.85s	remaining: 1.19s
# 609:	learn: 0.0409969	total: 1.85s	remaining: 1.19s
# 610:	learn: 0.0409186	total: 1.86s	remaining: 1.18s
# 611:	learn: 0.0408391	total: 1.86s	remaining: 1.18s
# 612:	learn: 0.0408207	total: 1.86s	remaining: 1.18s
# 613:	learn: 0.0407467	total: 1.86s	remaining: 1.17s
# 614:	learn: 0.0406752	total: 1.87s	remaining: 1.17s
# 615:	learn: 0.0406036	total: 1.87s	remaining: 1.16s
# 616:	learn: 0.0405200	total: 1.87s	remaining: 1.16s
# 617:	learn: 0.0404569	total: 1.87s	remaining: 1.16s
# 618:	learn: 0.0403864	total: 1.88s	remaining: 1.16s
# 619:	learn: 0.0402884	total: 1.88s	remaining: 1.15s
# 620:	learn: 0.0402059	total: 1.88s	remaining: 1.15s
# 621:	learn: 0.0401044	total: 1.89s	remaining: 1.15s
# 622:	learn: 0.0400394	total: 1.89s	remaining: 1.14s
# 623:	learn: 0.0399667	total: 1.89s	remaining: 1.14s
# 624:	learn: 0.0398606	total: 1.89s	remaining: 1.14s
# 625:	learn: 0.0397961	total: 1.9s	remaining: 1.13s
# 626:	learn: 0.0397004	total: 1.9s	remaining: 1.13s
# 627:	learn: 0.0396272	total: 1.9s	remaining: 1.13s
# 628:	learn: 0.0395552	total: 1.9s	remaining: 1.12s
# 629:	learn: 0.0394929	total: 1.91s	remaining: 1.12s
# 630:	learn: 0.0394032	total: 1.91s	remaining: 1.12s
# 631:	learn: 0.0392944	total: 1.91s	remaining: 1.11s
# 632:	learn: 0.0392639	total: 1.91s	remaining: 1.11s
# 633:	learn: 0.0392077	total: 1.92s	remaining: 1.11s
# 634:	learn: 0.0391132	total: 1.92s	remaining: 1.1s
# 635:	learn: 0.0390344	total: 1.92s	remaining: 1.1s
# 636:	learn: 0.0389421	total: 1.93s	remaining: 1.1s
# 637:	learn: 0.0388634	total: 1.93s	remaining: 1.09s
# 638:	learn: 0.0387945	total: 1.93s	remaining: 1.09s
# 639:	learn: 0.0387099	total: 1.93s	remaining: 1.09s
# 640:	learn: 0.0386140	total: 1.94s	remaining: 1.08s
# 641:	learn: 0.0385478	total: 1.94s	remaining: 1.08s
# 642:	learn: 0.0384807	total: 1.94s	remaining: 1.08s
# 643:	learn: 0.0383962	total: 1.94s	remaining: 1.07s
# 644:	learn: 0.0383025	total: 1.95s	remaining: 1.07s
# 645:	learn: 0.0382417	total: 1.95s	remaining: 1.07s
# 646:	learn: 0.0381741	total: 1.95s	remaining: 1.06s
# 647:	learn: 0.0380988	total: 1.96s	remaining: 1.06s
# 648:	learn: 0.0380626	total: 1.96s	remaining: 1.06s
# 649:	learn: 0.0379735	total: 1.96s	remaining: 1.06s
# 650:	learn: 0.0379078	total: 1.97s	remaining: 1.05s
# 651:	learn: 0.0378497	total: 1.97s	remaining: 1.05s
# 652:	learn: 0.0377383	total: 1.97s	remaining: 1.05s
# 653:	learn: 0.0376458	total: 1.97s	remaining: 1.04s
# 654:	learn: 0.0375664	total: 1.98s	remaining: 1.04s
# 655:	learn: 0.0375049	total: 1.98s	remaining: 1.04s
# 656:	learn: 0.0374204	total: 1.98s	remaining: 1.03s
# 657:	learn: 0.0373726	total: 1.98s	remaining: 1.03s
# 658:	learn: 0.0372986	total: 1.99s	remaining: 1.03s
# 659:	learn: 0.0372152	total: 1.99s	remaining: 1.02s
# 660:	learn: 0.0371462	total: 1.99s	remaining: 1.02s
# 661:	learn: 0.0370825	total: 2s	remaining: 1.02s
# 662:	learn: 0.0370291	total: 2s	remaining: 1.01s
# 663:	learn: 0.0369599	total: 2s	remaining: 1.01s
# 664:	learn: 0.0369054	total: 2s	remaining: 1.01s
# 665:	learn: 0.0368378	total: 2.01s	remaining: 1.01s
# 666:	learn: 0.0367747	total: 2.01s	remaining: 1s
# 667:	learn: 0.0367030	total: 2.01s	remaining: 1000ms
# 668:	learn: 0.0366388	total: 2.01s	remaining: 997ms
# 669:	learn: 0.0365594	total: 2.02s	remaining: 994ms
# 670:	learn: 0.0364959	total: 2.02s	remaining: 991ms
# 671:	learn: 0.0364027	total: 2.02s	remaining: 987ms
# 672:	learn: 0.0363223	total: 2.02s	remaining: 984ms
# 673:	learn: 0.0362260	total: 2.03s	remaining: 981ms
# 674:	learn: 0.0361830	total: 2.03s	remaining: 978ms
# 675:	learn: 0.0361005	total: 2.03s	remaining: 975ms
# 676:	learn: 0.0360401	total: 2.04s	remaining: 972ms
# 677:	learn: 0.0359651	total: 2.04s	remaining: 968ms
# 678:	learn: 0.0359059	total: 2.04s	remaining: 965ms
# 679:	learn: 0.0358428	total: 2.04s	remaining: 962ms
# 680:	learn: 0.0357694	total: 2.05s	remaining: 959ms
# 681:	learn: 0.0356910	total: 2.05s	remaining: 956ms
# 682:	learn: 0.0356245	total: 2.05s	remaining: 953ms
# 683:	learn: 0.0355370	total: 2.06s	remaining: 949ms
# 684:	learn: 0.0354786	total: 2.06s	remaining: 946ms
# 685:	learn: 0.0354075	total: 2.06s	remaining: 943ms
# 725:	learn: 0.0432965	total: 18.5s	remaining: 6.99s
# 726:	learn: 0.0432144	total: 18.5s	remaining: 6.96s
# 727:	learn: 0.0431842	total: 18.6s	remaining: 6.94s
# 728:	learn: 0.0431301	total: 18.6s	remaining: 6.91s
# 729:	learn: 0.0430430	total: 18.6s	remaining: 6.89s
# 730:	learn: 0.0430318	total: 18.7s	remaining: 6.86s
# 731:	learn: 0.0429574	total: 18.7s	remaining: 6.84s
# 732:	learn: 0.0429113	total: 18.7s	remaining: 6.81s
# 733:	learn: 0.0428716	total: 18.7s	remaining: 6.79s
# 734:	learn: 0.0428091	total: 18.8s	remaining: 6.76s
# 735:	learn: 0.0427612	total: 18.8s	remaining: 6.74s
# 736:	learn: 0.0426865	total: 18.8s	remaining: 6.71s
# 737:	learn: 0.0425925	total: 18.8s	remaining: 6.69s
# 738:	learn: 0.0425623	total: 18.9s	remaining: 6.66s
# 739:	learn: 0.0424918	total: 18.9s	remaining: 6.64s
# 740:	learn: 0.0424083	total: 18.9s	remaining: 6.61s
# 741:	learn: 0.0423800	total: 19s	remaining: 6.59s
# 742:	learn: 0.0423767	total: 19s	remaining: 6.56s
# 743:	learn: 0.0423138	total: 19s	remaining: 6.54s
# 744:	learn: 0.0422554	total: 19s	remaining: 6.51s
# 745:	learn: 0.0422329	total: 19s	remaining: 6.48s
# 746:	learn: 0.0421333	total: 19.1s	remaining: 6.46s
# 747:	learn: 0.0420654	total: 19.1s	remaining: 6.43s
# 748:	learn: 0.0419863	total: 19.1s	remaining: 6.41s
# 749:	learn: 0.0419302	total: 19.1s	remaining: 6.38s
# 750:	learn: 0.0418455	total: 19.2s	remaining: 6.36s
# 751:	learn: 0.0417323	total: 19.2s	remaining: 6.33s
# 752:	learn: 0.0417107	total: 19.2s	remaining: 6.31s
# 753:	learn: 0.0416578	total: 19.3s	remaining: 6.28s
# 754:	learn: 0.0415860	total: 19.3s	remaining: 6.25s
# 755:	learn: 0.0415297	total: 19.3s	remaining: 6.23s
# 756:	learn: 0.0414792	total: 19.3s	remaining: 6.21s
# 757:	learn: 0.0414390	total: 19.4s	remaining: 6.18s
# 758:	learn: 0.0413724	total: 19.4s	remaining: 6.16s
# 759:	learn: 0.0412947	total: 19.4s	remaining: 6.13s
# 760:	learn: 0.0412275	total: 19.4s	remaining: 6.11s
# 761:	learn: 0.0412222	total: 19.5s	remaining: 6.08s
# 762:	learn: 0.0411780	total: 19.5s	remaining: 6.05s
# 763:	learn: 0.0411219	total: 19.5s	remaining: 6.03s
# 764:	learn: 0.0410809	total: 19.5s	remaining: 6s
# 765:	learn: 0.0410771	total: 19.6s	remaining: 5.97s
# 766:	learn: 0.0410482	total: 19.6s	remaining: 5.95s
# 767:	learn: 0.0409836	total: 19.6s	remaining: 5.92s
# 768:	learn: 0.0409066	total: 19.6s	remaining: 5.9s
# 769:	learn: 0.0408644	total: 19.7s	remaining: 5.87s
# 770:	learn: 0.0408055	total: 19.7s	remaining: 5.85s
# 771:	learn: 0.0407495	total: 19.7s	remaining: 5.82s
# 772:	learn: 0.0406786	total: 19.7s	remaining: 5.8s
# 773:	learn: 0.0406326	total: 19.8s	remaining: 5.77s
# 774:	learn: 0.0405891	total: 19.8s	remaining: 5.75s
# 775:	learn: 0.0405694	total: 19.8s	remaining: 5.72s
# 776:	learn: 0.0405252	total: 19.8s	remaining: 5.7s
# 777:	learn: 0.0404830	total: 19.9s	remaining: 5.67s
# 778:	learn: 0.0404191	total: 19.9s	remaining: 5.64s
# 779:	learn: 0.0403471	total: 19.9s	remaining: 5.62s
# 780:	learn: 0.0403195	total: 20s	remaining: 5.59s
# 781:	learn: 0.0402499	total: 20s	remaining: 5.57s
# 782:	learn: 0.0401861	total: 20s	remaining: 5.54s
# 783:	learn: 0.0401263	total: 20s	remaining: 5.52s
# 784:	learn: 0.0400588	total: 20.1s	remaining: 5.49s
# 785:	learn: 0.0399673	total: 20.1s	remaining: 5.47s
# 786:	learn: 0.0399206	total: 20.1s	remaining: 5.44s
# 787:	learn: 0.0398650	total: 20.1s	remaining: 5.42s
# 788:	learn: 0.0398040	total: 20.2s	remaining: 5.39s
# 789:	learn: 0.0397241	total: 20.2s	remaining: 5.37s
# 790:	learn: 0.0396728	total: 20.2s	remaining: 5.34s
# 791:	learn: 0.0396640	total: 20.3s	remaining: 5.32s
# 792:	learn: 0.0396031	total: 20.3s	remaining: 5.29s
# 793:	learn: 0.0395312	total: 20.3s	remaining: 5.27s
# 794:	learn: 0.0395078	total: 20.3s	remaining: 5.24s
# 795:	learn: 0.0394659	total: 20.4s	remaining: 5.22s
# 796:	learn: 0.0394536	total: 20.4s	remaining: 5.19s
# 797:	learn: 0.0393674	total: 20.4s	remaining: 5.17s
# 798:	learn: 0.0393143	total: 20.4s	remaining: 5.14s
# 799:	learn: 0.0392342	total: 20.5s	remaining: 5.12s
# 800:	learn: 0.0392087	total: 20.5s	remaining: 5.09s
# 801:	learn: 0.0391567	total: 20.5s	remaining: 5.07s
# 802:	learn: 0.0391045	total: 20.5s	remaining: 5.04s
# 803:	learn: 0.0390879	total: 20.6s	remaining: 5.01s
# 804:	learn: 0.0390383	total: 20.6s	remaining: 4.99s
# 805:	learn: 0.0389721	total: 20.6s	remaining: 4.96s
# 806:	learn: 0.0389443	total: 20.6s	remaining: 4.94s
# 807:	learn: 0.0389093	total: 20.7s	remaining: 4.91s
# 808:	learn: 0.0388498	total: 20.7s	remaining: 4.89s
# 809:	learn: 0.0387954	total: 20.7s	remaining: 4.86s
# 810:	learn: 0.0387390	total: 20.8s	remaining: 4.84s
# 811:	learn: 0.0386731	total: 20.8s	remaining: 4.81s
# 812:	learn: 0.0386161	total: 20.8s	remaining: 4.79s
# 813:	learn: 0.0385101	total: 20.8s	remaining: 4.76s
# 814:	learn: 0.0384737	total: 20.9s	remaining: 4.74s
# 815:	learn: 0.0384296	total: 20.9s	remaining: 4.71s
# 816:	learn: 0.0383992	total: 20.9s	remaining: 4.69s
# 817:	learn: 0.0383457	total: 20.9s	remaining: 4.66s
# 818:	learn: 0.0383035	total: 21s	remaining: 4.63s
# 866:	learn: 0.0356943	total: 22.3s	remaining: 3.41s
# 867:	learn: 0.0356456	total: 22.3s	remaining: 3.39s
# 868:	learn: 0.0355730	total: 22.3s	remaining: 3.36s
# 869:	learn: 0.0355273	total: 22.3s	remaining: 3.34s
# 870:	learn: 0.0354779	total: 22.4s	remaining: 3.31s
# 871:	learn: 0.0354471	total: 22.4s	remaining: 3.29s
# 872:	learn: 0.0353831	total: 22.4s	remaining: 3.26s
# 873:	learn: 0.0353503	total: 22.4s	remaining: 3.24s
# 874:	learn: 0.0353001	total: 22.5s	remaining: 3.21s
# 875:	learn: 0.0352153	total: 22.5s	remaining: 3.19s
# 876:	learn: 0.0351807	total: 22.5s	remaining: 3.16s
# 877:	learn: 0.0351719	total: 22.6s	remaining: 3.13s
# 878:	learn: 0.0351699	total: 22.6s	remaining: 3.11s
# 879:	learn: 0.0351629	total: 22.6s	remaining: 3.08s
# 880:	learn: 0.0351305	total: 22.6s	remaining: 3.06s
# 881:	learn: 0.0351024	total: 22.7s	remaining: 3.03s
# 882:	learn: 0.0350670	total: 22.7s	remaining: 3s
# 883:	learn: 0.0350563	total: 22.7s	remaining: 2.98s
# 884:	learn: 0.0350195	total: 22.7s	remaining: 2.95s
# 885:	learn: 0.0349701	total: 22.8s	remaining: 2.93s
# 886:	learn: 0.0349635	total: 22.8s	remaining: 2.9s
# 887:	learn: 0.0348975	total: 22.8s	remaining: 2.88s
# 888:	learn: 0.0348764	total: 22.8s	remaining: 2.85s
# 889:	learn: 0.0347976	total: 22.9s	remaining: 2.83s
# 890:	learn: 0.0347559	total: 22.9s	remaining: 2.8s
# 891:	learn: 0.0347307	total: 22.9s	remaining: 2.77s
# 892:	learn: 0.0346599	total: 22.9s	remaining: 2.75s
# 893:	learn: 0.0346039	total: 23s	remaining: 2.72s
# 894:	learn: 0.0345506	total: 23s	remaining: 2.7s
# 895:	learn: 0.0344973	total: 23s	remaining: 2.67s
# 896:	learn: 0.0344423	total: 23.1s	remaining: 2.65s
# 897:	learn: 0.0344240	total: 23.1s	remaining: 2.62s
# 898:	learn: 0.0343950	total: 23.1s	remaining: 2.6s
# 899:	learn: 0.0343543	total: 23.1s	remaining: 2.57s
# 900:	learn: 0.0343195	total: 23.2s	remaining: 2.54s
# 901:	learn: 0.0342601	total: 23.2s	remaining: 2.52s
# 902:	learn: 0.0342301	total: 23.2s	remaining: 2.49s
# 903:	learn: 0.0341800	total: 23.2s	remaining: 2.47s
# 904:	learn: 0.0341394	total: 23.3s	remaining: 2.44s
# 905:	learn: 0.0340658	total: 23.3s	remaining: 2.42s
# 906:	learn: 0.0340280	total: 23.3s	remaining: 2.39s
# 907:	learn: 0.0339249	total: 23.4s	remaining: 2.37s
# 908:	learn: 0.0339024	total: 23.4s	remaining: 2.34s
# 909:	learn: 0.0338429	total: 23.4s	remaining: 2.31s
# 910:	learn: 0.0337872	total: 23.4s	remaining: 2.29s
# 911:	learn: 0.0337567	total: 23.5s	remaining: 2.26s
# 912:	learn: 0.0337046	total: 23.5s	remaining: 2.24s
# 913:	learn: 0.0336756	total: 23.5s	remaining: 2.21s
# 914:	learn: 0.0336682	total: 23.5s	remaining: 2.19s
# 915:	learn: 0.0336162	total: 23.6s	remaining: 2.16s
# 916:	learn: 0.0335741	total: 23.6s	remaining: 2.14s
# 917:	learn: 0.0335505	total: 23.6s	remaining: 2.11s
# 918:	learn: 0.0335203	total: 23.7s	remaining: 2.08s
# 919:	learn: 0.0334665	total: 23.7s	remaining: 2.06s
# 920:	learn: 0.0334018	total: 23.7s	remaining: 2.03s
# 921:	learn: 0.0333744	total: 23.7s	remaining: 2.01s
# 922:	learn: 0.0333651	total: 23.8s	remaining: 1.98s
# 923:	learn: 0.0333230	total: 23.8s	remaining: 1.96s
# 924:	learn: 0.0332968	total: 23.8s	remaining: 1.93s
# 925:	learn: 0.0332512	total: 23.8s	remaining: 1.91s
# 926:	learn: 0.0332007	total: 23.9s	remaining: 1.88s
# 927:	learn: 0.0331440	total: 23.9s	remaining: 1.85s
# 928:	learn: 0.0330712	total: 23.9s	remaining: 1.83s
# 929:	learn: 0.0330402	total: 24s	remaining: 1.8s
# 930:	learn: 0.0330251	total: 24s	remaining: 1.78s
# 931:	learn: 0.0329945	total: 24s	remaining: 1.75s
# 932:	learn: 0.0329442	total: 24s	remaining: 1.73s
# 933:	learn: 0.0328719	total: 24.1s	remaining: 1.7s
# 934:	learn: 0.0328384	total: 24.1s	remaining: 1.67s
# 935:	learn: 0.0328300	total: 24.1s	remaining: 1.65s
# 936:	learn: 0.0327835	total: 24.1s	remaining: 1.62s
# 937:	learn: 0.0327569	total: 24.2s	remaining: 1.6s
# 938:	learn: 0.0327153	total: 24.2s	remaining: 1.57s
# 939:	learn: 0.0326765	total: 24.2s	remaining: 1.55s
# 940:	learn: 0.0326175	total: 24.2s	remaining: 1.52s
# 941:	learn: 0.0325587	total: 24.3s	remaining: 1.49s
# 942:	learn: 0.0325310	total: 24.3s	remaining: 1.47s
# 943:	learn: 0.0325291	total: 24.3s	remaining: 1.44s
# 944:	learn: 0.0324924	total: 24.3s	remaining: 1.42s
# 945:	learn: 0.0324583	total: 24.4s	remaining: 1.39s
# 946:	learn: 0.0324172	total: 24.4s	remaining: 1.36s
# 947:	learn: 0.0323765	total: 24.4s	remaining: 1.34s
# 948:	learn: 0.0323434	total: 24.5s	remaining: 1.31s
# 949:	learn: 0.0323010	total: 24.5s	remaining: 1.29s
# 950:	learn: 0.0322747	total: 24.5s	remaining: 1.26s
# 951:	learn: 0.0321975	total: 24.5s	remaining: 1.24s
# 952:	learn: 0.0321906	total: 24.6s	remaining: 1.21s
# 953:	learn: 0.0321630	total: 24.6s	remaining: 1.19s
# 954:	learn: 0.0321281	total: 24.6s	remaining: 1.16s
# 955:	learn: 0.0320740	total: 24.6s	remaining: 1.13s
# 956:	learn: 0.0320334	total: 24.7s	remaining: 1.11s
# 957:	learn: 0.0319818	total: 24.7s	remaining: 1.08s
# 958:	learn: 0.0319629	total: 24.7s	remaining: 1.06s
# 959:	learn: 0.0319427	total: 24.7s	remaining: 1.03s
# 960:	learn: 0.0319296	total: 24.8s	remaining: 1s
# 961:	learn: 0.0318763	total: 24.8s	remaining: 980ms
# 962:	learn: 0.0318681	total: 24.8s	remaining: 954ms
# 963:	learn: 0.0318056	total: 24.9s	remaining: 928ms
# 964:	learn: 0.0317921	total: 24.9s	remaining: 902ms
# 965:	learn: 0.0317410	total: 24.9s	remaining: 877ms
# 966:	learn: 0.0316634	total: 24.9s	remaining: 851ms
# 967:	learn: 0.0316245	total: 25s	remaining: 825ms
# 968:	learn: 0.0315749	total: 25s	remaining: 799ms
# 969:	learn: 0.0315214	total: 25s	remaining: 774ms
# 970:	learn: 0.0314679	total: 25s	remaining: 748ms
# 971:	learn: 0.0314447	total: 25.1s	remaining: 722ms
# 972:	learn: 0.0314229	total: 25.1s	remaining: 696ms
# 973:	learn: 0.0313814	total: 25.1s	remaining: 671ms
# 974:	learn: 0.0313403	total: 25.1s	remaining: 645ms
# 975:	learn: 0.0312891	total: 25.2s	remaining: 619ms
# 976:	learn: 0.0312708	total: 25.2s	remaining: 593ms
# 977:	learn: 0.0312172	total: 25.2s	remaining: 568ms
# 978:	learn: 0.0311506	total: 25.3s	remaining: 542ms
# 979:	learn: 0.0311260	total: 25.3s	remaining: 516ms
# 980:	learn: 0.0310682	total: 25.3s	remaining: 490ms
# 981:	learn: 0.0310504	total: 25.3s	remaining: 464ms
# 982:	learn: 0.0310126	total: 25.4s	remaining: 439ms
# 983:	learn: 0.0309914	total: 25.4s	remaining: 413ms
# 984:	learn: 0.0309517	total: 25.4s	remaining: 387ms
# 985:	learn: 0.0309233	total: 25.4s	remaining: 361ms
# 986:	learn: 0.0308739	total: 25.5s	remaining: 335ms
# 987:	learn: 0.0308680	total: 25.5s	remaining: 310ms
# 988:	learn: 0.0308086	total: 25.5s	remaining: 284ms
# 989:	learn: 0.0307477	total: 25.6s	remaining: 258ms
# 990:	learn: 0.0307040	total: 25.6s	remaining: 232ms
# 991:	learn: 0.0306634	total: 25.6s	remaining: 206ms
# 992:	learn: 0.0306275	total: 25.6s	remaining: 181ms
# 993:	learn: 0.0305869	total: 25.7s	remaining: 155ms
# 994:	learn: 0.0305606	total: 25.7s	remaining: 129ms
# 995:	learn: 0.0305023	total: 25.7s	remaining: 103ms
# 996:	learn: 0.0304913	total: 25.7s	remaining: 77.4ms
# 997:	learn: 0.0304729	total: 25.8s	remaining: 51.6ms
# 998:	learn: 0.0304520	total: 25.8s	remaining: 25.8ms
# 999:	learn: 0.0304319	total: 25.8s	remaining: 0us
# Model Performance for CatBoost_Custom
# Gini prob is 98.56927710843372
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97        83
#            1       0.94      0.91      0.92        32
#
#     accuracy                           0.96       115
#    macro avg       0.95      0.94      0.95       115
# weighted avg       0.96      0.96      0.96       115
#
# [[81  2]
#  [ 3 29]]

# %%
gini_df_sorted
# Out:
#              Model  Gini_prob
# 2         CatBoost   0.987952
# 3  CatBoost_Custom   0.985693
# 0          XGBoost   0.978163
# 1         LightGBM   0.976657
