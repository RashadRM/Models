# %%
import pandas as pd  # Import pandas for data manipulation and analysis
import numpy as np  # Import numpy for numerical operations
from sklearn.model_selection import train_test_split  # Import train_test_split for splitting data into training and testing sets
from sklearn.preprocessing import StandardScaler, LabelEncoder  # Import StandardScaler for feature scaling and LabelEncoder for encoding target labels
from sklearn.linear_model import LogisticRegression  # Import LogisticRegression for logistic regression model
from sklearn.ensemble import RandomForestClassifier, StackingClassifier  # Import RandomForestClassifier for random forest model and StackingClassifier for model stacking
from sklearn.svm import SVC  # Import SVC for support vector classifier
from xgboost import XGBClassifier  # Import XGBClassifier for XGBoost model
from lightgbm import LGBMClassifier  # Import LGBMClassifier for LightGBM model
from catboost import CatBoostClassifier  # Import CatBoostClassifier for CatBoost model
from sklearn import metrics  # Import metrics from sklearn for model evaluation
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, roc_auc_score  # Import specific metrics for model evaluation
import warnings  # Import warnings to manage warnings
import category_encoders as ce  # Import category_encoders for encoding categorical features
import optuna
from sklearn.preprocessing import LabelEncoder
# Ignore warnings
warnings.filterwarnings('ignore')  # Suppress warnings for cleaner output

# %%
path = r'C:\Users\User\Desktop\Rashad\DATA\Credit Score Classification Dataset.csv'

# Load dataset from Excel file
df = pd.read_csv(path)

# Set option to display all columns
pd.set_option('display.max_columns', None)

#Display the loaded dataset
df
# Out:
#      Age  Gender  Income            Education Marital Status  \
# 0     25  Female   50000    Bachelor's Degree         Single
# 1     30    Male  100000      Master's Degree        Married
# 2     35  Female   75000            Doctorate        Married
# 3     40    Male  125000  High School Diploma         Single
# 4     45  Female  100000    Bachelor's Degree        Married
# ..   ...     ...     ...                  ...            ...
# 159   29  Female   27500  High School Diploma         Single
# 160   34    Male   47500   Associate's Degree         Single
# 161   39  Female   62500    Bachelor's Degree        Married
# 162   44    Male   87500      Master's Degree         Single
# 163   49  Female   77500            Doctorate        Married
#
#      Number of Children Home Ownership Credit Score
# 0                     0         Rented         High
# 1                     2          Owned         High
# 2                     1          Owned         High
# 3                     0          Owned         High
# 4                     3          Owned         High
# ..                  ...            ...          ...
# 159                   0         Rented          Low
# 160                   0         Rented      Average
# 161                   2          Owned         High
# 162                   0          Owned         High
# 163                   1          Owned         High
#
# [164 rows x 8 columns]

# %%
# Counting the occurrences of each value in the 'Credit Score' column
df['Credit Score'].value_counts()
# Out:
# Credit Score
# High       113
# Average     36
# Low         15
# Name: count, dtype: int64

# %%
# Instantiating a LabelEncoder object
label_encoder = LabelEncoder()

# %%
# Converting 'Credit Score' values to numeric values
# Assuming 'High' is considered as 1 and other values as 0
df['Credit Score'] = df['Credit Score'].apply(lambda x: 1 if x == 'High' else 0)

# %%
# Counting the occurrences of each value in the 'Credit Score' column after transformation
df['Credit Score'].value_counts()
# Out:
# Credit Score
# 1    113
# 0     51
# Name: count, dtype: int64

# %%
# Printing the columns of object data type in the DataFrame
print(df.select_dtypes('object').columns)
# Out:
# Index(['Gender', 'Education', 'Marital Status', 'Home Ownership'], dtype='object')

# %%
models = ["logistic_regression", "random_forest", "svc", "xgboost", "lightgbm", "catboost", "catboost_custom"]

# Create copies of the DataFrame for different preprocessing approaches
df_copy = df.copy()
df_boost = df.copy()
df_cat = df.copy()

# Iterate through each model in the list
for model in models:
    if model == "logistic_regression" or model == "svc":
        # Preprocessing for logistic regression and SVC models
        
        # Fill missing values with mean for numerical columns and mode for categorical columns
        for col in df_copy.columns:
            if df_copy[col].dtype in ['int64', 'float64']:
                df_copy[col] = df_copy[col].fillna(df_copy[col].mean())
            elif df_copy[col].dtype == 'object':
                df_copy[col] = df_copy[col].fillna(df_copy[col].mode().iloc[0])
        
        # Perform Weight of Evidence Encoding on all columns except the target column 'default'
        all_columns = df_copy.columns.tolist()
        all_columns.remove('Credit Score')
        encoder = ce.WOEEncoder(cols=all_columns)
        df_copy[all_columns] = encoder.fit_transform(df_copy[all_columns], df_copy['Credit Score'])
        
        # Remove duplicate rows and 'ID' column if exists
        df_copy.drop_duplicates(inplace=True)
        if 'ID' in df_copy.columns:
            df_copy.drop(columns=['ID'], inplace=True)
                
    elif model in ["random_forest", "xgboost", "lightgbm", "catboost"]:
        # Preprocessing for tree-based models
        
        # Perform Weight of Evidence Encoding on all columns except the target column 'default'
        all_columns = df_boost.columns.tolist()
        all_columns.remove('Credit Score')
        encoder = ce.WOEEncoder(cols=all_columns)
        df_boost[all_columns] = encoder.fit_transform(df_boost[all_columns], df_boost['Credit Score'])
             
    elif model ==  "catboost_custom":
        # Preprocessing for CatBoost with custom handling of missing values
        
        # Fill missing values in specified categorical columns with 'Missing Value'
        numerical_cols = df_cat.select_dtypes(include=['int64', 'float64']).columns.tolist()
        numerical_cols.remove('Credit Score')
        columns_to_fill = cat_features=['Gender', 'Education', 'Marital Status', 'Home Ownership']
        df_cat[columns_to_fill] = df_cat[columns_to_fill].fillna('Missing Value')
        
        # Perform Weight of Evidence Encoding on numerical columns
        encoder = ce.WOEEncoder(cols=numerical_cols)
        df_cat[numerical_cols] = encoder.fit_transform(df_cat[numerical_cols], df_cat['Credit Score'])

# Split data into features (X) and target (y) for each preprocessing approach
x_log = df_copy.drop(columns=['Credit Score'])
y_log = df_copy['Credit Score']
X_train_log, X_test_log, y_train_log, y_test_log = train_test_split(x_log, y_log, test_size=0.3, random_state=42)

x_boost = df_boost.drop(columns=['Credit Score'])
y_boost = df_boost['Credit Score']
X_train_boost, X_test_boost, y_train_boost, y_test_boost = train_test_split(x_boost, y_boost, test_size=0.3, random_state=42)

x_cat = df_cat.drop(columns=['Credit Score'])
y_cat = df_cat['Credit Score']
X_train_cat, X_test_cat, y_train_cat, y_test_cat = train_test_split(x_cat, y_cat, test_size=0.3, random_state=42)

# %%
models = []  # Initialize an empty list to store model definitions

# Define default models for each algorithm
xgb_model_def = XGBClassifier()
lgb_model_def = LGBMClassifier()
catboost_model_def = CatBoostClassifier()
catboost_model_custom = CatBoostClassifier(cat_features=['Gender', 'Education', 'Marital Status', 'Home Ownership'])
lg = LogisticRegression()
rf = RandomForestClassifier()
svc_model_def = SVC(probability=True)  # Add SVC model definition

# Define models for stacking
stacking_models = [('XGBoost', xgb_model_def),
                   ('LightGBM', lgb_model_def),
                   ('CatBoost', catboost_model_def),
                   ('CatBoost_Custom', catboost_model_custom),
                   ('LogisticRegression', lg),
                   ('RandomForest', rf),
                   ('SVC', svc_model_def)]  # Add SVC to stacking_models

# Extend models list with default models
models.extend([
    ('XGBoost', xgb_model_def),
    ('LightGBM', lgb_model_def),
    ('CatBoost', catboost_model_def),
    ('CatBoost_Custom', catboost_model_custom),
    ('LogisticRegression', lg),
    ('RandomForest', rf),
    ('SVC', svc_model_def)  # Add SVC to models list
])

# %%
def train_and_evaluate_model(model_name, model, X_train, y_train, X_test, y_test):
    """
    Train and evaluate the given model on the training and testing data.

    Parameters:
    model_name (str): Name of the model for display purposes.
    model : Machine learning model object.
    X_train : Features of the training data.
    y_train : Target labels of the training data.
    X_test : Features of the testing data.
    y_test : Target labels of the testing data.

    Returns:
    float: Gini coefficient calculated from the model's predictions.
    """

    # Fit the model on the training data
    model.fit(X_train, y_train)

    # Predict labels and probabilities on the testing data
    y_pred = model.predict(X_test)
    y_prob = model.predict_proba(X_test)[:, 1]

    # Calculate ROC AUC and Gini coefficient
    roc_prob = roc_auc_score(y_test, y_prob)
    gini_prob = roc_prob * 2 - 1

    # Calculate confusion matrix and classification report
    confusion_matrix_result = confusion_matrix(y_test, y_pred)
    classification_report_result = classification_report(y_test, y_pred)

    # Print model performance metrics
    print(f'Model Performance for {model_name}')
    print('Gini prob is', gini_prob * 100)
    print(classification_report_result)
    print(confusion_matrix_result)

    return gini_prob

# %%
gini_df = pd.DataFrame(columns=['Model', 'Gini_prob'])

# Iterate through each model in the list of models
for model_name, model in models:
    # Train and evaluate the model, and calculate the Gini coefficient
    if model_name == 'CatBoost_Custom':
        gini_prob = train_and_evaluate_model(model_name, model, X_train_cat, y_train_cat, X_test_cat, y_test_cat)
    elif model_name in ['LogisticRegression', 'SVC']:
        gini_prob = train_and_evaluate_model(model_name, model, X_train_log, y_train_log, X_test_log, y_test_log)
    else:
        gini_prob = train_and_evaluate_model(model_name, model, X_train_boost, y_train_boost, X_test_boost, y_test_boost)
        
    # Add model name and Gini coefficient to the DataFrame
    if gini_prob is not None:
        gini_df = pd.concat([gini_df, pd.DataFrame({'Model': [model_name], 'Gini_prob': [gini_prob]})], ignore_index=True)

# Sort the DataFrame by Gini coefficient in descending order
gini_df_sorted = gini_df.sort_values(by='Gini_prob', ascending=False)
# Out:
# Model Performance for XGBoost
# Gini prob is 97.56944444444446
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91        18
#            1       0.91      1.00      0.96        32
#
#     accuracy                           0.94        50
#    macro avg       0.96      0.92      0.93        50
# weighted avg       0.95      0.94      0.94        50
#
# [[15  3]
#  [ 0 32]]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 81, number of negative: 33
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001298 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 42
# [LightGBM] [Info] Number of data points in the train set: 114, number of used features: 7
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.710526 -> initscore=0.897942
# [LightGBM] [Info] Start training from score 0.897942
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Model Performance for LightGBM
# Gini prob is 96.52777777777777
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91        18
#            1       0.91      1.00      0.96        32
#
#     accuracy                           0.94        50
#    macro avg       0.96      0.92      0.93        50
# weighted avg       0.95      0.94      0.94        50
#
# [[15  3]
#  [ 0 32]]
# Learning rate set to 0.004076
# 0:	learn: 0.6860532	total: 198ms	remaining: 3m 17s
# 1:	learn: 0.6799977	total: 204ms	remaining: 1m 41s
# 2:	learn: 0.6732761	total: 209ms	remaining: 1m 9s
# 3:	learn: 0.6656348	total: 214ms	remaining: 53.3s
# 482:	learn: 0.0435039	total: 1.09s	remaining: 1.17s
# 483:	learn: 0.0433499	total: 1.09s	remaining: 1.17s
# 484:	learn: 0.0432702	total: 1.1s	remaining: 1.16s
# 485:	learn: 0.0431727	total: 1.1s	remaining: 1.16s
# 486:	learn: 0.0430123	total: 1.1s	remaining: 1.16s
# 487:	learn: 0.0428660	total: 1.1s	remaining: 1.15s
# 488:	learn: 0.0427222	total: 1.1s	remaining: 1.15s
# 489:	learn: 0.0425591	total: 1.1s	remaining: 1.15s
# 490:	learn: 0.0424426	total: 1.1s	remaining: 1.14s
# 491:	learn: 0.0423318	total: 1.1s	remaining: 1.14s
# 492:	learn: 0.0422016	total: 1.11s	remaining: 1.14s
# 493:	learn: 0.0420513	total: 1.11s	remaining: 1.13s
# 494:	learn: 0.0419161	total: 1.11s	remaining: 1.13s
# 495:	learn: 0.0418108	total: 1.11s	remaining: 1.13s
# 496:	learn: 0.0417418	total: 1.11s	remaining: 1.13s
# 497:	learn: 0.0416502	total: 1.11s	remaining: 1.12s
# 498:	learn: 0.0415535	total: 1.11s	remaining: 1.12s
# 499:	learn: 0.0414508	total: 1.11s	remaining: 1.11s
# 500:	learn: 0.0413719	total: 1.12s	remaining: 1.11s
# 501:	learn: 0.0412842	total: 1.12s	remaining: 1.11s
# 502:	learn: 0.0412076	total: 1.12s	remaining: 1.1s
# 503:	learn: 0.0411093	total: 1.12s	remaining: 1.1s
# 504:	learn: 0.0410480	total: 1.12s	remaining: 1.1s
# 505:	learn: 0.0408987	total: 1.12s	remaining: 1.1s
# 506:	learn: 0.0407791	total: 1.12s	remaining: 1.09s
# 507:	learn: 0.0406561	total: 1.13s	remaining: 1.09s
# 508:	learn: 0.0405600	total: 1.13s	remaining: 1.09s
# 509:	learn: 0.0404849	total: 1.13s	remaining: 1.08s
# 510:	learn: 0.0403988	total: 1.13s	remaining: 1.08s
# 511:	learn: 0.0403104	total: 1.13s	remaining: 1.08s
# 512:	learn: 0.0401959	total: 1.13s	remaining: 1.07s
# 513:	learn: 0.0400919	total: 1.13s	remaining: 1.07s
# 514:	learn: 0.0399836	total: 1.13s	remaining: 1.07s
# 515:	learn: 0.0398731	total: 1.14s	remaining: 1.06s
# 516:	learn: 0.0398003	total: 1.14s	remaining: 1.06s
# 517:	learn: 0.0396634	total: 1.14s	remaining: 1.06s
# 518:	learn: 0.0395707	total: 1.14s	remaining: 1.06s
# 519:	learn: 0.0394373	total: 1.14s	remaining: 1.05s
# 520:	learn: 0.0393200	total: 1.14s	remaining: 1.05s
# 521:	learn: 0.0392225	total: 1.14s	remaining: 1.05s
# 522:	learn: 0.0391343	total: 1.15s	remaining: 1.04s
# 523:	learn: 0.0390278	total: 1.15s	remaining: 1.04s
# 524:	learn: 0.0389608	total: 1.15s	remaining: 1.04s
# 525:	learn: 0.0388530	total: 1.15s	remaining: 1.03s
# 526:	learn: 0.0387243	total: 1.15s	remaining: 1.03s
# 527:	learn: 0.0386137	total: 1.15s	remaining: 1.03s
# 528:	learn: 0.0384950	total: 1.15s	remaining: 1.03s
# 830:	learn: 0.0244448	total: 9.58s	remaining: 1.95s
# 831:	learn: 0.0244100	total: 9.59s	remaining: 1.94s
# 832:	learn: 0.0243757	total: 9.61s	remaining: 1.93s
# 833:	learn: 0.0243534	total: 9.61s	remaining: 1.91s
# 834:	learn: 0.0243246	total: 9.63s	remaining: 1.9s
# 835:	learn: 0.0242905	total: 9.64s	remaining: 1.89s
# 836:	learn: 0.0242545	total: 9.65s	remaining: 1.88s
# 837:	learn: 0.0242274	total: 9.66s	remaining: 1.87s
# 838:	learn: 0.0241928	total: 9.67s	remaining: 1.85s
# 839:	learn: 0.0241724	total: 9.68s	remaining: 1.84s
# 840:	learn: 0.0241310	total: 9.7s	remaining: 1.83s
# 841:	learn: 0.0240884	total: 9.71s	remaining: 1.82s
# 842:	learn: 0.0240700	total: 9.72s	remaining: 1.81s
# 843:	learn: 0.0240398	total: 9.73s	remaining: 1.8s
# 844:	learn: 0.0239702	total: 9.74s	remaining: 1.79s
# 845:	learn: 0.0239112	total: 9.76s	remaining: 1.78s
# 846:	learn: 0.0238587	total: 9.77s	remaining: 1.76s
# 847:	learn: 0.0238244	total: 9.78s	remaining: 1.75s
# 848:	learn: 0.0237937	total: 9.79s	remaining: 1.74s
# 849:	learn: 0.0237405	total: 9.8s	remaining: 1.73s
# 850:	learn: 0.0236862	total: 9.82s	remaining: 1.72s
# 851:	learn: 0.0236470	total: 9.83s	remaining: 1.71s
# 852:	learn: 0.0236086	total: 9.84s	remaining: 1.7s
# 853:	learn: 0.0235696	total: 9.86s	remaining: 1.68s
# 854:	learn: 0.0235271	total: 9.86s	remaining: 1.67s
# 855:	learn: 0.0234747	total: 9.88s	remaining: 1.66s
# 856:	learn: 0.0234378	total: 9.88s	remaining: 1.65s
# 857:	learn: 0.0234168	total: 9.9s	remaining: 1.64s
# 858:	learn: 0.0233935	total: 9.91s	remaining: 1.63s
# 859:	learn: 0.0233420	total: 9.92s	remaining: 1.61s
# 860:	learn: 0.0233085	total: 9.93s	remaining: 1.6s
# 861:	learn: 0.0232578	total: 9.95s	remaining: 1.59s
# 862:	learn: 0.0232094	total: 9.96s	remaining: 1.58s
# 863:	learn: 0.0231627	total: 9.97s	remaining: 1.57s
# 864:	learn: 0.0231431	total: 9.98s	remaining: 1.56s
# 865:	learn: 0.0230996	total: 10s	remaining: 1.55s
# 866:	learn: 0.0230551	total: 10s	remaining: 1.53s
# 867:	learn: 0.0230067	total: 10s	remaining: 1.52s
# 868:	learn: 0.0229754	total: 10s	remaining: 1.51s
# 869:	learn: 0.0229369	total: 10s	remaining: 1.5s
# 870:	learn: 0.0229157	total: 10.1s	remaining: 1.49s
# 871:	learn: 0.0228780	total: 10.1s	remaining: 1.48s
# 872:	learn: 0.0228295	total: 10.1s	remaining: 1.47s
# 873:	learn: 0.0228136	total: 10.1s	remaining: 1.46s
# 874:	learn: 0.0227712	total: 10.1s	remaining: 1.44s
# 875:	learn: 0.0227373	total: 10.1s	remaining: 1.43s
# 876:	learn: 0.0227035	total: 10.1s	remaining: 1.42s
# 877:	learn: 0.0226722	total: 10.1s	remaining: 1.41s
# 878:	learn: 0.0226490	total: 10.2s	remaining: 1.4s
# 879:	learn: 0.0226144	total: 10.2s	remaining: 1.39s
# 880:	learn: 0.0225745	total: 10.2s	remaining: 1.37s
# 881:	learn: 0.0225608	total: 10.2s	remaining: 1.36s
# 882:	learn: 0.0225322	total: 10.2s	remaining: 1.35s
# 883:	learn: 0.0224831	total: 10.2s	remaining: 1.34s
# 884:	learn: 0.0224234	total: 10.2s	remaining: 1.33s
# 885:	learn: 0.0223889	total: 10.2s	remaining: 1.32s
# 886:	learn: 0.0223495	total: 10.2s	remaining: 1.3s
# 887:	learn: 0.0223208	total: 10.3s	remaining: 1.29s
# 888:	learn: 0.0222825	total: 10.3s	remaining: 1.28s
# 889:	learn: 0.0222548	total: 10.3s	remaining: 1.27s
# 890:	learn: 0.0222062	total: 10.3s	remaining: 1.26s
# 891:	learn: 0.0221770	total: 10.3s	remaining: 1.25s
# 892:	learn: 0.0221477	total: 10.3s	remaining: 1.24s
# 893:	learn: 0.0220968	total: 10.3s	remaining: 1.23s
# 894:	learn: 0.0220688	total: 10.3s	remaining: 1.21s
# 895:	learn: 0.0220253	total: 10.4s	remaining: 1.2s
# 896:	learn: 0.0220105	total: 10.4s	remaining: 1.19s
# 897:	learn: 0.0219658	total: 10.4s	remaining: 1.18s
# 898:	learn: 0.0219338	total: 10.4s	remaining: 1.17s
# 899:	learn: 0.0218923	total: 10.4s	remaining: 1.16s
# 900:	learn: 0.0218460	total: 10.4s	remaining: 1.15s
# 901:	learn: 0.0218262	total: 10.4s	remaining: 1.13s
# 902:	learn: 0.0217995	total: 10.4s	remaining: 1.12s
# 903:	learn: 0.0217739	total: 10.5s	remaining: 1.11s
# 904:	learn: 0.0217312	total: 10.5s	remaining: 1.1s
# 905:	learn: 0.0216939	total: 10.5s	remaining: 1.09s
# 906:	learn: 0.0216574	total: 10.5s	remaining: 1.07s
# 907:	learn: 0.0216184	total: 10.5s	remaining: 1.06s
# 908:	learn: 0.0215822	total: 10.5s	remaining: 1.05s
# 909:	learn: 0.0215526	total: 10.5s	remaining: 1.04s
# 910:	learn: 0.0215025	total: 10.5s	remaining: 1.03s
# 911:	learn: 0.0214722	total: 10.6s	remaining: 1.02s
# 912:	learn: 0.0214365	total: 10.6s	remaining: 1.01s
# 913:	learn: 0.0213907	total: 10.6s	remaining: 995ms
# 914:	learn: 0.0213521	total: 10.6s	remaining: 984ms
# 915:	learn: 0.0213215	total: 10.6s	remaining: 972ms
# 916:	learn: 0.0212934	total: 10.6s	remaining: 961ms
# 917:	learn: 0.0212719	total: 10.6s	remaining: 950ms
# 918:	learn: 0.0212575	total: 10.6s	remaining: 938ms
# 919:	learn: 0.0212116	total: 10.7s	remaining: 927ms
# 920:	learn: 0.0211819	total: 10.7s	remaining: 915ms
# 921:	learn: 0.0211370	total: 10.7s	remaining: 904ms
# 922:	learn: 0.0211144	total: 10.7s	remaining: 892ms
# 972:	learn: 0.0195789	total: 11.3s	remaining: 315ms
# 973:	learn: 0.0195652	total: 11.4s	remaining: 303ms
# 974:	learn: 0.0195386	total: 11.4s	remaining: 291ms
# 975:	learn: 0.0195171	total: 11.4s	remaining: 280ms
# 976:	learn: 0.0194839	total: 11.4s	remaining: 268ms
# 977:	learn: 0.0194409	total: 11.4s	remaining: 256ms
# 978:	learn: 0.0194092	total: 11.4s	remaining: 245ms
# 979:	learn: 0.0193761	total: 11.4s	remaining: 233ms
# 980:	learn: 0.0193581	total: 11.4s	remaining: 222ms
# 981:	learn: 0.0193290	total: 11.4s	remaining: 210ms
# 982:	learn: 0.0193018	total: 11.5s	remaining: 198ms
# 983:	learn: 0.0192769	total: 11.5s	remaining: 187ms
# 984:	learn: 0.0192472	total: 11.5s	remaining: 175ms
# 985:	learn: 0.0192108	total: 11.5s	remaining: 163ms
# 986:	learn: 0.0191926	total: 11.5s	remaining: 152ms
# 987:	learn: 0.0191493	total: 11.5s	remaining: 140ms
# 988:	learn: 0.0191261	total: 11.5s	remaining: 128ms
# 989:	learn: 0.0190982	total: 11.6s	remaining: 117ms
# 990:	learn: 0.0190650	total: 11.6s	remaining: 105ms
# 991:	learn: 0.0190226	total: 11.6s	remaining: 93.3ms
# 992:	learn: 0.0190081	total: 11.6s	remaining: 81.7ms
# 993:	learn: 0.0189835	total: 11.6s	remaining: 70ms
# 994:	learn: 0.0189714	total: 11.6s	remaining: 58.3ms
# 995:	learn: 0.0189408	total: 11.6s	remaining: 46.7ms
# 996:	learn: 0.0189093	total: 11.6s	remaining: 35ms
# 997:	learn: 0.0188964	total: 11.6s	remaining: 23.3ms
# 998:	learn: 0.0188816	total: 11.7s	remaining: 11.7ms
# 999:	learn: 0.0188514	total: 11.7s	remaining: 0us
# Model Performance for CatBoost_Custom
# Gini prob is 98.9583333333333
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0.91        18
#            1       0.94      0.97      0.95        32
#
#     accuracy                           0.94        50
#    macro avg       0.94      0.93      0.93        50
# weighted avg       0.94      0.94      0.94        50
#
# [[16  2]
#  [ 1 31]]
# Model Performance for LogisticRegression
# Gini prob is 95.53571428571428
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94         8
#            1       1.00      0.93      0.96        14
#
#     accuracy                           0.95        22
#    macro avg       0.94      0.96      0.95        22
# weighted avg       0.96      0.95      0.96        22
#
# [[ 8  0]
#  [ 1 13]]
# Model Performance for RandomForest
# Gini prob is 98.4375
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94        18
#            1       0.94      1.00      0.97        32
#
#     accuracy                           0.96        50
#    macro avg       0.97      0.94      0.96        50
# weighted avg       0.96      0.96      0.96        50
#
# [[16  2]
#  [ 0 32]]
# Model Performance for SVC
# Gini prob is 93.75
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94         8
#            1       1.00      0.93      0.96        14
#
#     accuracy                           0.95        22
#    macro avg       0.94      0.96      0.95        22
# weighted avg       0.96      0.95      0.96        22
#
# [[ 8  0]
#  [ 1 13]]

# %%
gini_df_sorted
# Out:
#                 Model  Gini_prob
# 2            CatBoost   0.989583
# 3     CatBoost_Custom   0.989583
# 5        RandomForest   0.984375
# 0             XGBoost   0.975694
# 1            LightGBM   0.965278
# 4  LogisticRegression   0.955357
# 6                 SVC   0.937500
